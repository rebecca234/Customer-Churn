# %% [markdown]
# <h3 style='color:blue' align='center'>Customer Churn Prediction Using Artificial Neural Network (ANN)</h3>

# %% [markdown]
# Customer churn prediction is to measure why customers are leaving a business. We worked on the customer churn in telecom business. We will build a deep learning model to predict the churn and use precision,recall, f1-score to measure performance of our model

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from keras.optimizers import Adam
from keras.layers import Dropout
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix , classification_report
from sklearn.model_selection import train_test_split



# %matplotlib inline
# Out:
# 2024-05-17 11:10:24.799721: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-17 11:10:24.800304: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-17 11:10:25.012662: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-17 11:10:25.612874: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-17 11:10:27.410733: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# **Load the data**

# %%
dataset = pd.read_csv("Telco-Customer-Churn.csv")
dataset.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3327  9494-BDNNC    Male              0     Yes         No      66
# 371   0259-GBZSH    Male              0      No         No       2
# 6394  2680-XKKNJ  Female              0      No         No       8
# 5641  7452-FOLON    Male              0      No        Yes      39
# 4634  9426-SXNHE  Female              0      No         No       2
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 3327          Yes           Yes     Fiber optic                   No  ...
# 371           Yes           Yes     Fiber optic                   No  ...
# 6394          Yes            No             DSL                  Yes  ...
# 5641          Yes           Yes              No  No internet service  ...
# 4634          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3327                  Yes                   No                   No
# 371                    No                   No                  Yes
# 6394                   No                  Yes                   No
# 5641  No internet service  No internet service  No internet service
# 4634  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 3327                  Yes        One year               No
# 371                    No  Month-to-month              Yes
# 6394                   No        One year               No
# 5641  No internet service        One year               No
# 4634  No internet service  Month-to-month               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 3327           Electronic check          95.30        6273.4    No
# 371            Electronic check          85.65         181.5   Yes
# 6394  Bank transfer (automatic)          58.20        469.25    No
# 5641  Bank transfer (automatic)          25.45        958.45    No
# 4634  Bank transfer (automatic)          18.75         53.15    No
#
# [5 rows x 21 columns]

# %% [markdown]
# **First of all, drop customerID column as it is of no use**

# %%
dataset.drop('customerID',axis='columns',inplace=True)

# %%
dataset.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object
